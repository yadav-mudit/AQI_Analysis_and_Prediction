# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('data.csv',encoding='unicode_escape')
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_7332\1402922042.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data.csv',encoding='unicode_escape')

# %%
df.head()
# Out:
#   stn_code       sampling_date           state   location agency  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN
# 1                     Industrial Area  3.1   7.0   NaN  NaN
# 2  Residential, Rural and other Areas  6.2  28.5   NaN  NaN
# 3  Residential, Rural and other Areas  6.3  14.7   NaN  NaN
# 4                     Industrial Area  4.7   7.5   NaN  NaN
#
#   location_monitoring_station  pm2_5        date
# 0                         NaN    NaN  1990-02-01
# 1                         NaN    NaN  1990-02-01
# 2                         NaN    NaN  1990-02-01
# ...

# %%
df.shape
# Out:
# (435742, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435742 entries, 0 to 435741
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   stn_code                     291665 non-null  object
#  1   sampling_date                435739 non-null  object
#  2   state                        435742 non-null  object
#  3   location                     435739 non-null  object
#  4   agency                       286261 non-null  object
#  5   type                         430349 non-null  object
#  6   so2                          401096 non-null  float64
#  7   no2                          419509 non-null  float64
#  8   rspm                         395520 non-null  float64
#  9   spm                          198355 non-null  float64
#  10  location_monitoring_station  408251 non-null  object
#  11  pm2_5                        9314 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# stn_code                       144077
# sampling_date                       3
# state                               0
# location                            3
# agency                         149481
# type                             5393
# so2                             34646
# no2                             16233
# rspm                            40222
# spm                            237387
# location_monitoring_station     27491
# pm2_5                          426428
# date                                7
# dtype: int64

# %%
df.describe()
# Out:
#                  so2            no2           rspm            spm        pm2_5
# count  401096.000000  419509.000000  395520.000000  198355.000000  9314.000000
# mean       10.829414      25.809623     108.832784     220.783480    40.791467
# std        11.177187      18.503086      74.872430     151.395457    30.832525
# min         0.000000       0.000000       0.000000       0.000000     3.000000
# 25%         5.000000      14.000000      56.000000     111.000000    24.000000
# 50%         8.000000      22.000000      90.000000     187.000000    32.000000
# 75%        13.700000      32.200000     142.000000     296.000000    46.000000
# max       909.000000     876.000000    6307.033333    3380.000000   504.000000

# %%
#EXPLORATORY DATA ANALYSIS

# %%
sns.pairplot(df)
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df['state'].value_counts()
# Out:
# state
# Maharashtra                    60384
# Uttar Pradesh                  42816
# Andhra Pradesh                 26368
# Punjab                         25634
# Rajasthan                      25589
# Kerala                         24728
# Himachal Pradesh               22896
# West Bengal                    22463
# Gujarat                        21279
# Tamil Nadu                     20597
# Madhya Pradesh                 19920
# Assam                          19361
# Odisha                         19279
# Karnataka                      17119
# Delhi                           8551
# Chandigarh                      8520
# Chhattisgarh                    7831
# Goa                             6206
# Jharkhand                       5968
# Mizoram                         5338
# Telangana                       3978
# Meghalaya                       3853
# Puducherry                      3785
# Haryana                         3420
# Nagaland                        2463
# ...

# %%
plt.figure(figsize = (15,8))
sns.countplot(df,y='state')
# Out:
# <Axes: xlabel='count', ylabel='state'>

# %%
df['type'].value_counts()
# Out:
# type
# Residential, Rural and other Areas    179014
# Industrial Area                        96091
# Residential and others                 86791
# Industrial Areas                       51747
# Sensitive Area                          8980
# Sensitive Areas                         5536
# RIRUO                                   1304
# Sensitive                                495
# Industrial                               233
# Residential                              158
# Name: count, dtype: int64

# %%
sns.countplot(df,y='type')
# Out:
# <Axes: xlabel='count', ylabel='type'>

# %%
plt.figure(figsize = (15,8))
sns.barplot(df,y='state',x='so2')
# Out:
# <Axes: xlabel='so2', ylabel='state'>

# %%
plt.figure(figsize = (15,8))
sns.barplot(df,y='state',x='no2')
# Out:
# <Axes: xlabel='no2', ylabel='state'>

# %%
plt.figure(figsize = (15,8))
sns.barplot(df,y='state',x='rspm')
# Out:
# <Axes: xlabel='rspm', ylabel='state'>

# %%
plt.figure(figsize = (15,8))
sns.barplot(df,y='state',x='spm')
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning:
#
# Mean of empty slice
#
# C:\Users\KIIT\anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1556: RuntimeWarning:
#
# All-NaN slice encountered
# <Axes: xlabel='spm', ylabel='state'>

# %%
plt.figure(figsize = (15,8))
sns.barplot(df,y='state',x='pm2_5')
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning:
#
# Mean of empty slice
#
# C:\Users\KIIT\anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1556: RuntimeWarning:
#
# All-NaN slice encountered
# <Axes: xlabel='pm2_5', ylabel='state'>

# %%
#CHECKING AND TREATING NULL VALUES

# %%
nullvalues = df.isnull().sum().sort_values(ascending=False)

# %%
nullvalues
# Out:
# pm2_5                          426428
# spm                            237387
# agency                         149481
# stn_code                       144077
# rspm                            40222
# so2                             34646
# location_monitoring_station     27491
# no2                             16233
# type                             5393
# date                                7
# sampling_date                       3
# location                            3
# state                               0
# dtype: int64

# %%
#we drop the columns not needed

# %%
df.drop(['agency'],axis=1,inplace=True)
df.drop(['stn_code'],axis=1,inplace=True)
df.drop(['date'],axis=1,inplace=True)
df.drop(['sampling_date'],axis=1,inplace=True)
df.drop(['location_monitoring_station'],axis=1,inplace=True)

# %%
df.head()
# Out:
#             state   location                                type  so2   no2  \
# 0  Andhra Pradesh  Hyderabad  Residential, Rural and other Areas  4.8  17.4
# 1  Andhra Pradesh  Hyderabad                     Industrial Area  3.1   7.0
# 2  Andhra Pradesh  Hyderabad  Residential, Rural and other Areas  6.2  28.5
# 3  Andhra Pradesh  Hyderabad  Residential, Rural and other Areas  6.3  14.7
# 4  Andhra Pradesh  Hyderabad                     Industrial Area  4.7   7.5
#
#    rspm  spm  pm2_5
# 0   NaN  NaN    NaN
# 1   NaN  NaN    NaN
# 2   NaN  NaN    NaN
# 3   NaN  NaN    NaN
# 4   NaN  NaN    NaN

# %%
df['location'].fillna(value = df['location'].mode()[0],inplace=True)

# %%
df['location'].isnull().sum()
# Out:
# 0

# %%
df['type'].fillna(df['type'].mode()[0],inplace=True)

# %%
df['type'].isnull().sum()
# Out:
# 0

# %%
df.fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# state       0
# location    0
# type        0
# so2         0
# no2         0
# rspm        0
# spm         0
# pm2_5       0
# SOi         0
# dtype: int64

# %%
#CALC. INDIVIDUAL POLLUTANT INDEX

# %%
def cal_SOi(so2):
    si=0
    if (so2<=40):
     si= so2*(50/40)
    elif (so2>40 and so2<=80):
     si= 50+(so2-40)*(50/40)
    elif (so2>80 and so2<=380):
     si= 100+(so2-80)*(100/300)
    elif (so2>380 and so2<=800):
     si= 200+(so2-380)*(100/420)
    elif (so2>800 and so2<=1600):
     si= 300+(so2-800)*(100/800)
    elif (so2>1600):
     si= 400+(so2-1600)*(100/800)
    return si
df['SOi']=df['so2'].apply(cal_SOi)

# %%
def cal_Noi(no2):
    ni=0
    if(no2<=40):
     ni= no2*50/40
    elif(no2>40 and no2<=80):
     ni= 50+(no2-40)*(50/40)
    elif(no2>80 and no2<=180):
     ni= 100+(no2-80)*(100/100)
    elif(no2>180 and no2<=280):
     ni= 200+(no2-180)*(100/100)
    elif(no2>280 and no2<=400):
     ni= 300+(no2-280)*(100/120)
    else:
     ni= 400+(no2-400)*(100/120)
    return ni
df['Noi']=df['no2'].apply(cal_Noi)

# %%
def cal_RSPMI(rspm):
    rpi=0
    if(rpi<=30):
     rpi=rpi*50/30
    elif(rpi>30 and rpi<=60):
     rpi=50+(rpi-30)*50/30
    elif(rpi>60 and rpi<=90):
     rpi=100+(rpi-60)*100/30
    elif(rpi>90 and rpi<=120):
     rpi=200+(rpi-90)*100/30
    elif(rpi>120 and rpi<=250):
     rpi=300+(rpi-120)*(100/130)
    else:
     rpi=400+(rpi-250)*(100/130)
    return rpi
df['Rpi']=df['rspm'].apply(cal_RSPMI)

# %%
def cal_SPMi(spm):
    spi=0
    if(spm<=50):
     spi=spm*50/50
    elif(spm>50 and spm<=100):
     spi=50+(spm-50)*(50/50)
    elif(spm>100 and spm<=250):
     spi= 100+(spm-100)*(100/150)
    elif(spm>250 and spm<=350):
     spi=200+(spm-250)*(100/100)
    elif(spm>350 and spm<=430):
     spi=300+(spm-350)*(100/80)
    else:
     spi=400+(spm-430)*(100/430)
    return spi
   
df['SPMi']=df['spm'].apply(cal_SPMi)
data= df[['spm','SPMi']]

# %%
def cal_aqi(si,ni,rspmi,spmi):
    aqi=0
    if(si>ni and si>rspmi and si>spmi):
     aqi=si
    if(ni>si and ni>rspmi and ni>spmi):
     aqi=ni
    if(rspmi>si and rspmi>ni and rspmi>spmi):
     aqi=rspmi
    if(spmi>si and spmi>ni and spmi>rspmi):
     aqi=spmi
    return aqi

df['AQI']=df.apply(lambda x:cal_aqi(x['SOi'],x['Noi'],x['Rpi'],x['SPMi']),axis=1)

# %%
df.head()
# Out:
#             state   location                                type  so2   no2  \
# 0  Andhra Pradesh  Hyderabad  Residential, Rural and other Areas  4.8  17.4
# 1  Andhra Pradesh  Hyderabad                     Industrial Area  3.1   7.0
# 2  Andhra Pradesh  Hyderabad  Residential, Rural and other Areas  6.2  28.5
# 3  Andhra Pradesh  Hyderabad  Residential, Rural and other Areas  6.3  14.7
# 4  Andhra Pradesh  Hyderabad                     Industrial Area  4.7   7.5
#
#    rspm  spm  pm2_5    SOi     Noi  Rpi  SPMi     AQI
# 0   0.0  0.0    0.0  6.000  21.750  0.0   0.0  21.750
# 1   0.0  0.0    0.0  3.875   8.750  0.0   0.0   8.750
# 2   0.0  0.0    0.0  7.750  35.625  0.0   0.0  35.625
# 3   0.0  0.0    0.0  7.875  18.375  0.0   0.0  18.375
# 4   0.0  0.0    0.0  5.875   9.375  0.0   0.0   9.375

# %%
#TRAINING ML MODELS

# %%
from sklearn.model_selection import train_test_split

# %%
df.columns
# Out:
# Index(['state', 'location', 'type', 'so2', 'no2', 'rspm', 'spm', 'pm2_5',
#        'SOi', 'Noi', 'Rpi', 'SPMi', 'AQI'],
#       dtype='object')

# %%
X = df[['SOi', 'Noi', 'Rpi', 'SPMi']]
y= df['AQI']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred = lm.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
print("Mean Absolute Error: {}\nMean Squared Error: {}\nRoot Mean Squared Error: {}".format(mean_absolute_error(y_test,pred),mean_squared_error(y_test,pred),np.sqrt(mean_squared_error(y_test,pred))))
# Out:
# Mean Absolute Error: 9.165150122956312
# Mean Squared Error: 183.79183649992072
# Root Mean Squared Error: 13.556984786445721

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
pred_rf = rf.predict(X_test)

# %%
print("Mean Absolute Error: {}\nMean Squared Error: {}\nRoot Mean Squared Error: {}".format(mean_absolute_error(y_test,pred_rf),mean_squared_error(y_test,pred_rf),np.sqrt(mean_squared_error(y_test,pred_rf))))
# Out:
# Mean Absolute Error: 0.03338804975945368
# Mean Squared Error: 0.875076726532753
# Root Mean Squared Error: 0.9354553578513264

# %%
X2 = df[['so2', 'no2', 'rspm', 'spm']]
y2= df['AQI']

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.3)

# %%
lm2 = LinearRegression()

# %%
lm2.fit(X2_train,y2_train)
# Out:
# LinearRegression()

# %%
pred2 = lm2.predict(X2_test)

# %%
print("Mean Absolute Error: {}\nMean Squared Error: {}\nRoot Mean Squared Error: {}".format(mean_absolute_error(y2_test,pred2),mean_squared_error(y2_test,pred2),np.sqrt(mean_squared_error(y2_test,pred2))))
# Out:
# Mean Absolute Error: 10.660624915075076
# Mean Squared Error: 366.69080130263234
# Root Mean Squared Error: 19.149172339885407

# %%
sns.scatterplot(x=y2_test,y=pred2)
# Out:
# <Axes: xlabel='AQI'>

# %%
sns.scatterplot(x=y_test,y=pred)
# Out:
# <Axes: xlabel='AQI'>
